# %%
import pandas as pd


path="mcc_codes.csv"
data = pd.read_csv(path)
data
# Out:
#       mcc                                 edited_description  \
# 0     742                                Veterinary Services
# 1     763                         Agricultural Co-operatives
# 2     780       Horticultural Services, Landscaping Services
# 3    1520     General Contractors-Residential and Commercial
# 4    1711  Air Conditioning Contractors – Sales and Insta...
# 5    1731                             Electrical Contractors
# 6    1740  Insulation – Contractors, Masonry, Stonework C...
# 7    1750                              Carpentry Contractors
# 8    1761  Roofing – Contractors, Sheet Metal Work – Cont...
# 9    1771                        Contractors – Concrete Work
# 10   1799  Contractors – Special Trade, Not Elsewhere Cla...
# 11   2741              Miscellaneous Publishing and Printing
# 12   2791      Typesetting, Plate Making, & Related Services
# 13   2842  Specialty Cleaning, Polishing, and Sanitation ...
# ...

# %%
len(data)
# Out:
# 981

# %%
vals_to_replace = {'otros':'Otros'}
data['Categorias'] = data['5_Categoria'].map(vals_to_replace)
data["5_Categoria"] = data["5_Categoria"].fillna("Otros")

# %%
data.head(20)
# Out:
#      mcc                                 edited_description  \
# 0    742                                Veterinary Services
# 1    763                         Agricultural Co-operatives
# 2    780       Horticultural Services, Landscaping Services
# 3   1520     General Contractors-Residential and Commercial
# 4   1711  Air Conditioning Contractors – Sales and Insta...
# 5   1731                             Electrical Contractors
# 6   1740  Insulation – Contractors, Masonry, Stonework C...
# 7   1750                              Carpentry Contractors
# 8   1761  Roofing – Contractors, Sheet Metal Work – Cont...
# 9   1771                        Contractors – Concrete Work
# 10  1799  Contractors – Special Trade, Not Elsewhere Cla...
# 11  2741              Miscellaneous Publishing and Printing
# 12  2791      Typesetting, Plate Making, & Related Services
# 13  2842  Specialty Cleaning, Polishing, and Sanitation ...
# 14  3000                                    UNITED AIRLINES
# ...
